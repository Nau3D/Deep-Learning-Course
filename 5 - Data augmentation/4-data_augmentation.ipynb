# %% [markdown]
# # Data augmentation
#
# This notebook explores data augmentation as a mean to increase the accuracy, particularly on the test set

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping,TensorBoard, ReduceLROnPlateau
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization, LeakyReLU 
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

import os
import numpy as np

# plotting
import matplotlib.pyplot as plt
import pathlib
from PIL import Image
import IPython.display as display

# to display confusion matrix
import seaborn as sn
import pandas as pd

# %% [markdown]
# ### Aux functions

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  return parts[-2] == classNames

def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_png(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [32,32])

def get_bytes_and_label(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

def show_data(s1,l1, s2,l2, labels, min):
    fig, ax = plt.subplots()
    X = np.arange(len(s1))

    models = labels
    plt.bar(X, s1, width = 0.4, color = 'b', label=l1)
    plt.bar(X + 0.4, s2, color = 'r', width = 0.4, label = l2)
    plt.xticks(X + 0.4 / 2, models)
    plt.ylim(top = 100, bottom = min)
    plt.legend(loc='upper left')
    plt.show()

def show_batch(image_batch, label_batch):
  columns = 8
  rows = BATCH_SIZE / columns + 1  
  plt.figure(figsize=(10, 2 * rows))
  for n in range(BATCH_SIZE):
      ax = plt.subplot(int(rows), columns, n+1)
      plt.imshow((image_batch[n]))
      plt.title(classNames[label_batch[n]==1][0])
      plt.axis('off')


def show_history(history):
    print(history.history.keys())

    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='lower right')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper right')
    plt.show()    


def show_accuracies(labels, test, val): 

    fig, ax = plt.subplots()
    X = np.arange(len(test))

    plt.bar(X, test, width = 0.4, color = 'b', label='test')
    plt.bar(X + 0.4, val, color = 'r', width = 0.4, label = "val")
    plt.xticks(X + 0.4 / 2, labels)
    plt.ylim(top = 1.0, bottom = 0.97)
    plt.legend(loc='upper left')
    plt.show()    



def show_misclassified(predictions, ground_truth, images, num_rows = 5, num_cols=3):
    
    # Plot the first X test images with wrong predictions.
    num_images = num_rows*num_cols
    print(num_images)
    plt.figure(figsize=(2*2*num_cols, 2*num_rows))
    i = 0
    k = 0
    while k < len(images) and i < num_images:
        predicted_label = np.argmax(predictions[k])
        gt = np.where(ground_truth[k])[0][0]
        if predicted_label != gt:
            plt.subplot(num_rows, 2*num_cols, 2*i+1)
            plot_image(k, predictions[k], gt, images)
            plt.subplot(num_rows, 2*num_cols, 2*i+2)
            plot_value_array(k, predictions[k], ground_truth)
            i += 1
        k += 1
    plt.tight_layout()
    plt.show()


def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label, img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.binary)
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
      color = 'blue'
    else:
      color = 'red'
    
    plt.xlabel("{} {:2.0f}% ({})".format(classNames[predicted_label],
                                100*np.max(predictions_array),
                                classNames[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(8))
    plt.yticks([])
    thisplot = plt.bar(range(8), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[np.where(true_label)[0][0]].set_color('blue')   



def show_confusion_matrix(mat, classes):

    df_cm = pd.DataFrame(mat, range(classes), range(classes))
    plt.figure(figsize=(8,6))
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='d') # font size

    plt.show()

# %% [markdown]
# ## Callbacks
#
# Here we introduce a new callback: ReduceLROnPlateau: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ReduceLROnPlateau
#
# When the model is trapped in an area where no improvement can be achieved, it is sometimes benefic to reduce the learning rate.

# %%
def prepare_callbacks(file_path):

    checkpointer = ModelCheckpoint(filepath= file_path, 
                               monitor = 'val_accuracy',
                               verbose=1, 
                               save_weights_only=True,
                               save_best_only=True)


    earlyStopper = EarlyStopping(monitor='val_loss', min_delta = 0.0001, patience = 15, verbose = 1)

    reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.000000001, verbose = 1)

    return [checkpointer, earlyStopper, reduceLR]

# %% [markdown]
# ## Batch size
#
# Batch size is an important parameter when training a network. It can influence speed and generalization, not necessarily in the same direction. There is no golden rule for the batch size but 32 is a commom number to start with.
#
# In here we go to 64 to achieve faster training epochs (rather than 32)
#
# See: https://machinelearningmastery.com/how-to-control-the-speed-and-stability-of-training-neural-networks-with-gradient-descent-batch-size/

# %%
BATCH_SIZE = 64
IMAGE_SIZE = 32

# %% [markdown]
# ## Settings

# %%
data_path = 'c:/work/vcpi/gtsrb'
log_and_model_path = 'c:/work/vcpi/dl05/'

# %% [markdown]
# ### Prepare to load images

# %%
classNames = np.array(os.listdir(f'{data_path}/train'))
classNames
# Out:
# array(['00000', '00001', '00002', '00003', '00004', '00005', '00006',
#        '00007'], dtype='<U5')

# %% [markdown]
# ### Loading images takes place in here

# %%
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

dataset = tf.keras.preprocessing.image_dataset_from_directory(
    f'{data_path}/train',
    batch_size = None,
    label_mode = 'categorical',
    image_size=(32,32),
    shuffle=True)
 
normalize = tf.keras.layers.Rescaling(1.0/255) 
dataset = dataset.map(lambda x, y: (normalize(x), y))
# Out:
# Found 10200 files belonging to 8 classes.

# %% [markdown]
# ### Information about image shape and size of training set

# %%
t = next(iter(dataset))
print(t[0].shape, t[1].shape)

# note: this only works if dataset is not repeating
dataset_length = dataset.cardinality().numpy()
print("Total images in dataset: ", dataset_length)
# Out:
# (32, 32, 3) (8,)
# Total images in dataset:  10200

# %% [markdown]
# # Version I - training with dataset only

# %% [markdown]
# ### Preparing training, validation and test datasets

# %%
dataSolo = dataset
dataSolo = dataSolo.cache()
dataSolo = dataSolo.shuffle(buffer_size = dataset_length)
dataSolo = dataSolo.prefetch(buffer_size=10200)
dataSolo = dataSolo.batch(batch_size=BATCH_SIZE)

# %%
valset = tf.keras.preprocessing.image_dataset_from_directory(
    f'{data_path}/val',
    image_size = (32, 32),
    batch_size = None,
    label_mode = 'categorical',
    shuffle = True)
 
valset = valset.map(lambda x, y: (normalize(x), y))

valset = valset.cache()
valset = valset.batch(batch_size = 2580)
valset = valset.prefetch(buffer_size = AUTOTUNE)
# Out:
# Found 2580 files belonging to 8 classes.

# %%
testset = tf.keras.preprocessing.image_dataset_from_directory(
    f'{data_path}/test',
    image_size = (32, 32),
    batch_size = 128,
    label_mode = 'categorical',
    shuffle = True)

testset = testset.map(lambda x, y: (normalize(x), y))
# Out:
# Found 4170 files belonging to 8 classes.

# %% [markdown]
# ### Show a batch of training images

# %%
image_batch, label_batch = next(iter(dataSolo))        
show_batch(image_batch, label_batch.numpy())

# %% [markdown]
# ### Build a CNN network

# %%
def model_III(classCount, imgSize, channels):

    model = Sequential()
    
    model.add(Conv2D(128, (5, 5), 
                     input_shape=(imgSize, imgSize, channels)
                     ))         
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.01))   
    
    model.add(Conv2D(128, (5, 5) )) 
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.01))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(256, (5, 5) ) )   
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.01))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(128))
    model.add(LeakyReLU(alpha=0.01))             
    model.add(Dropout(0.2))

    model.add(Dense(classCount, activation='softmax'))

    
    opt = Adam(lr=0.0001)
    model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=[ 'accuracy'])
    return model

# %%
modelV1 = model_III(8, 32, 3)

print(modelV1.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 128)       9728
#
#  leaky_re_lu (LeakyReLU)     (None, 28, 28, 128)       0
#
#  batch_normalization (BatchN  (None, 28, 28, 128)      512
#  ormalization)
#
#  dropout (Dropout)           (None, 28, 28, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 196)       627396
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 24, 24, 196)       0
#
#  batch_normalization_1 (Batc  (None, 24, 24, 196)      784
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 196)      0
#  )
#
#  dropout_1 (Dropout)         (None, 12, 12, 196)       0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 256)         1254656
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 8, 8, 256)         0
#
#  batch_normalization_2 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 384)               1573248
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 384)               0
#
#  dropout_3 (Dropout)         (None, 384)               0
#
#  dense_1 (Dense)             (None, 8)                 3080
#
# =================================================================
# Total params: 3,470,428
# Trainable params: 3,469,268
# Non-trainable params: 1,160
# _________________________________________________________________
# None

# %% [markdown]
# ### Train the network

# %%
file_pathV1 = f'{log_and_model_path}/V1/cp.ckpt'

# %%
callbacksV1 = prepare_callbacks(file_pathV1)

historyV1 = modelV1.fit(dataSolo,
          epochs = 50, 
          validation_data = valset, 
          callbacks = callbacksV1)
# Out:
# Epoch 1/50
# 319/319 [==============================] - ETA: 0s - loss: 2.4831 - accuracy: 0.2681
# Epoch 1: val_accuracy improved from -inf to 0.16202, saving model to c:/work/vcpi/dl05//V1\cp.ckpt
# 319/319 [==============================] - 14s 24ms/step - loss: 2.4831 - accuracy: 0.2681 - val_loss: 3.1446 - val_accuracy: 0.1620 - lr: 1.0000e-04
# Epoch 2/50
# 319/319 [==============================] - ETA: 0s - loss: 1.6516 - accuracy: 0.3862
# Epoch 2: val_accuracy improved from 0.16202 to 0.40736, saving model to c:/work/vcpi/dl05//V1\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 1.6516 - accuracy: 0.3862 - val_loss: 2.4433 - val_accuracy: 0.4074 - lr: 1.0000e-04
# Epoch 3/50
# 317/319 [============================>.] - ETA: 0s - loss: 1.0993 - accuracy: 0.5916
# Epoch 3: val_accuracy improved from 0.40736 to 0.73566, saving model to c:/work/vcpi/dl05//V1\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 1.0976 - accuracy: 0.5926 - val_loss: 0.8014 - val_accuracy: 0.7357 - lr: 1.0000e-04
# Epoch 4/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.5816 - accuracy: 0.7932
# Epoch 4: val_accuracy improved from 0.73566 to 0.90891, saving model to c:/work/vcpi/dl05//V1\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.5806 - accuracy: 0.7936 - val_loss: 0.3087 - val_accuracy: 0.9089 - lr: 1.0000e-04
# Epoch 5/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.3523 - accuracy: 0.8801
# Epoch 5: val_accuracy improved from 0.90891 to 0.94070, saving model to c:/work/vcpi/dl05//V1\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.3523 - accuracy: 0.8799 - val_loss: 0.1893 - val_accuracy: 0.9407 - lr: 1.0000e-04
# Epoch 6/50
# 316/319 [============================>.] - ETA: 0s - loss: 0.2263 - accuracy: 0.9204
# Epoch 6: val_accuracy improved from 0.94070 to 0.95543, saving model to c:/work/vcpi/dl05//V1\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.2261 - accuracy: 0.9205 - val_loss: 0.1329 - val_accuracy: 0.9554 - lr: 1.0000e-04
# Epoch 7/50
# 317/319 [============================>.] - ETA: 0s - loss: 0.1691 - accuracy: 0.9403
# Epoch 7: val_accuracy did not improve from 0.95543
# 319/319 [==============================] - 6s 18ms/step - loss: 0.1688 - accuracy: 0.9404 - val_loss: 0.1644 - val_accuracy: 0.9512 - lr: 1.0000e-04
# Epoch 8/50
# 316/319 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9593
# Epoch 8: val_accuracy improved from 0.95543 to 0.95620, saving model to c:/work/vcpi/dl05//V1\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.1263 - accuracy: 0.9594 - val_loss: 0.1261 - val_accuracy: 0.9562 - lr: 1.0000e-04
# Epoch 9/50
# Epoch 46: val_accuracy did not improve from 0.98721
# 319/319 [==============================] - 6s 18ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0554 - val_accuracy: 0.9833 - lr: 6.2500e-06
# Epoch 47/50
# 316/319 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9990
# Epoch 47: val_accuracy did not improve from 0.98721
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 319/319 [==============================] - 6s 18ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0542 - val_accuracy: 0.9829 - lr: 6.2500e-06
# Epoch 48/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9984
# Epoch 48: val_accuracy did not improve from 0.98721
# 319/319 [==============================] - 6s 18ms/step - loss: 0.0042 - accuracy: 0.9984 - val_loss: 0.0547 - val_accuracy: 0.9826 - lr: 3.1250e-06
# Epoch 49/50
# 316/319 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9987
# Epoch 49: val_accuracy did not improve from 0.98721
# 319/319 [==============================] - 6s 18ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.0560 - val_accuracy: 0.9833 - lr: 3.1250e-06
# Epoch 50/50
# 316/319 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9980
# Epoch 50: val_accuracy did not improve from 0.98721
# 319/319 [==============================] - 6s 18ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0550 - val_accuracy: 0.9826 - lr: 3.1250e-06

# %% [markdown]
# ### Plot the training history

# %%
show_history(historyV1)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %% [markdown]
# ### Evaluate Model

# %%
modelV1.load_weights(file_pathV1)

evalV1 = modelV1.evaluate(testset, verbose=2)
valV1 = modelV1.evaluate(valset, verbose=2)
trainV1 = modelV1.evaluate(dataSolo, verbose=2)
# Out:
# 33/33 - 1s - loss: 0.0904 - accuracy: 0.9791 - 1s/epoch - 37ms/step
# 1/1 - 0s - loss: 0.0462 - accuracy: 0.9872 - 499ms/epoch - 499ms/step
# 319/319 - 2s - loss: 2.0676e-05 - accuracy: 1.0000 - 2s/epoch - 5ms/step

# %% [markdown]
# # Version II - dynamic data augmentation

# %% [markdown]
# ### Function to transform image

# %%
import tensorflow_addons as tfa


def process_image(image, label):
    
    # random rotate 5 degrees
    r = tf.random.uniform(shape=(), minval=-0.175, maxval=0.175, dtype=tf.dtypes.float32)
    image = tfa.image.rotate(image, r)

    # translate image up to 10%
    rx = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32) 
    ry = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32) 
    image = tfa.image.translate(image, [rx, ry])
   
    # change hue, saturation and value
    image = tfa.image.random_hsv_in_yiq(image, 0.2, 0.4, 1.1, 0.4, 1.1)
    image = tf.clip_by_value(image,0,1)

    return image, label
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
dataV2 = dataset
dataV2 = dataV2.cache()
dataV2 = dataV2.shuffle(buffer_size = dataset_length)
dataV2 = dataV2.map(process_image)
dataV2 = dataV2.prefetch(buffer_size=10200)
dataV2 = dataV2.batch(batch_size=BATCH_SIZE)

# %%
modelV2 = model_III(8, 32, 3)

file_pathV2 = f'{log_and_model_path}/DA_modelV2/cp.ckpt'

# %%
callbacksV2 = prepare_callbacks(file_pathV2)

historyV2 = modelV2.fit(dataV2,
          epochs = 50, 
          validation_data = valset, 
          callbacks = callbacksV2)
# Out:
# Epoch 1/50
# 318/319 [============================>.] - ETA: 0s - loss: 2.6335 - accuracy: 0.2135
# Epoch 1: val_accuracy improved from -inf to 0.01163, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 8s 19ms/step - loss: 2.6312 - accuracy: 0.2139 - val_loss: 4.0944 - val_accuracy: 0.0116 - lr: 1.0000e-04
# Epoch 2/50
# 319/319 [==============================] - ETA: 0s - loss: 1.9630 - accuracy: 0.2509
# Epoch 2: val_accuracy improved from 0.01163 to 0.13023, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 19ms/step - loss: 1.9630 - accuracy: 0.2509 - val_loss: 4.0603 - val_accuracy: 0.1302 - lr: 1.0000e-04
# Epoch 3/50
# 317/319 [============================>.] - ETA: 0s - loss: 1.8755 - accuracy: 0.2699
# Epoch 3: val_accuracy improved from 0.13023 to 0.30155, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 19ms/step - loss: 1.8744 - accuracy: 0.2700 - val_loss: 2.1659 - val_accuracy: 0.3016 - lr: 1.0000e-04
# Epoch 4/50
# 319/319 [==============================] - ETA: 0s - loss: 1.7776 - accuracy: 0.3172
# Epoch 4: val_accuracy improved from 0.30155 to 0.34380, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 1.7776 - accuracy: 0.3172 - val_loss: 1.9671 - val_accuracy: 0.3438 - lr: 1.0000e-04
# Epoch 5/50
# 318/319 [============================>.] - ETA: 0s - loss: 1.6452 - accuracy: 0.3719
# Epoch 5: val_accuracy improved from 0.34380 to 0.47248, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 5s 17ms/step - loss: 1.6450 - accuracy: 0.3722 - val_loss: 1.4492 - val_accuracy: 0.4725 - lr: 1.0000e-04
# Epoch 6/50
# 319/319 [==============================] - ETA: 0s - loss: 1.4362 - accuracy: 0.4615
# Epoch 6: val_accuracy improved from 0.47248 to 0.66395, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 5s 17ms/step - loss: 1.4362 - accuracy: 0.4615 - val_loss: 0.9847 - val_accuracy: 0.6640 - lr: 1.0000e-04
# Epoch 7/50
# 319/319 [==============================] - ETA: 0s - loss: 1.1534 - accuracy: 0.5757
# Epoch 7: val_accuracy improved from 0.66395 to 0.85039, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 1.1534 - accuracy: 0.5757 - val_loss: 0.4804 - val_accuracy: 0.8504 - lr: 1.0000e-04
# Epoch 8/50
# 317/319 [============================>.] - ETA: 0s - loss: 0.8749 - accuracy: 0.6836
# Epoch 8: val_accuracy improved from 0.85039 to 0.91473, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.8733 - accuracy: 0.6840 - val_loss: 0.2808 - val_accuracy: 0.9147 - lr: 1.0000e-04
# Epoch 9/50
# 319/319 [==============================] - ETA: 0s - loss: 0.6542 - accuracy: 0.7742
# Epoch 9: val_accuracy improved from 0.91473 to 0.92636, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.6542 - accuracy: 0.7742 - val_loss: 0.2697 - val_accuracy: 0.9264 - lr: 1.0000e-04
# Epoch 10/50
# 316/319 [============================>.] - ETA: 0s - loss: 0.5091 - accuracy: 0.8222
# Epoch 10: val_accuracy improved from 0.92636 to 0.95775, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.5090 - accuracy: 0.8223 - val_loss: 0.1357 - val_accuracy: 0.9578 - lr: 1.0000e-04
# Epoch 11/50
# 319/319 [==============================] - ETA: 0s - loss: 0.4053 - accuracy: 0.8607
# Epoch 11: val_accuracy improved from 0.95775 to 0.96822, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.4053 - accuracy: 0.8607 - val_loss: 0.1014 - val_accuracy: 0.9682 - lr: 1.0000e-04
# Epoch 12/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.3194 - accuracy: 0.8885
# Epoch 12: val_accuracy did not improve from 0.96822
# 319/319 [==============================] - 6s 18ms/step - loss: 0.3195 - accuracy: 0.8884 - val_loss: 0.1473 - val_accuracy: 0.9550 - lr: 1.0000e-04
# Epoch 13/50
# 317/319 [============================>.] - ETA: 0s - loss: 0.2577 - accuracy: 0.9130
# Epoch 13: val_accuracy did not improve from 0.96822
# 319/319 [==============================] - 6s 18ms/step - loss: 0.2581 - accuracy: 0.9128 - val_loss: 0.1501 - val_accuracy: 0.9539 - lr: 1.0000e-04
# Epoch 14/50
# 317/319 [============================>.] - ETA: 0s - loss: 0.2248 - accuracy: 0.9220
# Epoch 14: val_accuracy improved from 0.96822 to 0.97403, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.2249 - accuracy: 0.9220 - val_loss: 0.0748 - val_accuracy: 0.9740 - lr: 1.0000e-04
# Epoch 15/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.1960 - accuracy: 0.9301
# Epoch 15: val_accuracy improved from 0.97403 to 0.97752, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.1958 - accuracy: 0.9301 - val_loss: 0.0605 - val_accuracy: 0.9775 - lr: 1.0000e-04
# Epoch 16/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.1755 - accuracy: 0.9395
# Epoch 16: val_accuracy did not improve from 0.97752
# 319/319 [==============================] - 6s 18ms/step - loss: 0.1756 - accuracy: 0.9394 - val_loss: 0.0719 - val_accuracy: 0.9721 - lr: 1.0000e-04
# Epoch 17/50
# 319/319 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9441
# Epoch 17: val_accuracy improved from 0.97752 to 0.98062, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.1615 - accuracy: 0.9441 - val_loss: 0.0608 - val_accuracy: 0.9806 - lr: 1.0000e-04
# Epoch 18/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.1465 - accuracy: 0.9513
# Epoch 18: val_accuracy did not improve from 0.98062
# 319/319 [==============================] - 6s 18ms/step - loss: 0.1462 - accuracy: 0.9514 - val_loss: 0.0563 - val_accuracy: 0.9798 - lr: 1.0000e-04
# Epoch 19/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.1401 - accuracy: 0.9523
# Epoch 19: val_accuracy did not improve from 0.98062
# 319/319 [==============================] - 6s 18ms/step - loss: 0.1398 - accuracy: 0.9525 - val_loss: 0.0666 - val_accuracy: 0.9740 - lr: 1.0000e-04
# Epoch 20/50
# 317/319 [============================>.] - ETA: 0s - loss: 0.1212 - accuracy: 0.9587
# Epoch 20: val_accuracy improved from 0.98062 to 0.98101, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.1211 - accuracy: 0.9587 - val_loss: 0.0473 - val_accuracy: 0.9810 - lr: 1.0000e-04
# Epoch 21/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.1028 - accuracy: 0.9670
# Epoch 21: val_accuracy did not improve from 0.98101
# 319/319 [==============================] - 6s 17ms/step - loss: 0.1031 - accuracy: 0.9669 - val_loss: 0.0961 - val_accuracy: 0.9643 - lr: 1.0000e-04
# Epoch 22/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.1138 - accuracy: 0.9622
# Epoch 22: val_accuracy did not improve from 0.98101
# 319/319 [==============================] - 6s 18ms/step - loss: 0.1139 - accuracy: 0.9622 - val_loss: 0.2037 - val_accuracy: 0.9341 - lr: 1.0000e-04
# Epoch 23/50
# 319/319 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9708
# Epoch 23: val_accuracy improved from 0.98101 to 0.98798, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.0868 - accuracy: 0.9708 - val_loss: 0.0309 - val_accuracy: 0.9880 - lr: 1.0000e-04
# Epoch 24/50
# 316/319 [============================>.] - ETA: 0s - loss: 0.0895 - accuracy: 0.9702
# Epoch 24: val_accuracy did not improve from 0.98798
# 319/319 [==============================] - 6s 17ms/step - loss: 0.0892 - accuracy: 0.9702 - val_loss: 0.0834 - val_accuracy: 0.9690 - lr: 1.0000e-04
# Epoch 25/50
# 319/319 [==============================] - 6s 17ms/step - loss: 0.0265 - accuracy: 0.9907 - val_loss: 0.0231 - val_accuracy: 0.9946 - lr: 2.5000e-05
# Epoch 44/50
# 316/319 [============================>.] - ETA: 0s - loss: 0.0300 - accuracy: 0.9895
# Epoch 44: val_accuracy improved from 0.99457 to 0.99496, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 319/319 [==============================] - 6s 18ms/step - loss: 0.0300 - accuracy: 0.9895 - val_loss: 0.0242 - val_accuracy: 0.9950 - lr: 2.5000e-05
# Epoch 45/50
# 317/319 [============================>.] - ETA: 0s - loss: 0.0253 - accuracy: 0.9895
# Epoch 45: val_accuracy improved from 0.99496 to 0.99574, saving model to c:/work/vcpi/dl05//DA_modelV2\cp.ckpt
# 319/319 [==============================] - 6s 18ms/step - loss: 0.0252 - accuracy: 0.9895 - val_loss: 0.0133 - val_accuracy: 0.9957 - lr: 1.2500e-05
# Epoch 46/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.0278 - accuracy: 0.9909
# Epoch 46: val_accuracy did not improve from 0.99574
# 319/319 [==============================] - 6s 18ms/step - loss: 0.0278 - accuracy: 0.9909 - val_loss: 0.0156 - val_accuracy: 0.9938 - lr: 1.2500e-05
# Epoch 47/50
# 316/319 [============================>.] - ETA: 0s - loss: 0.0265 - accuracy: 0.9918
# Epoch 47: val_accuracy did not improve from 0.99574
# 319/319 [==============================] - 6s 17ms/step - loss: 0.0267 - accuracy: 0.9918 - val_loss: 0.0204 - val_accuracy: 0.9938 - lr: 1.2500e-05
# Epoch 48/50
# 318/319 [============================>.] - ETA: 0s - loss: 0.0254 - accuracy: 0.9922
# Epoch 48: val_accuracy did not improve from 0.99574
# 319/319 [==============================] - 6s 17ms/step - loss: 0.0254 - accuracy: 0.9923 - val_loss: 0.0168 - val_accuracy: 0.9957 - lr: 1.2500e-05
# Epoch 49/50
# 319/319 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9917
# Epoch 49: val_accuracy did not improve from 0.99574
# 319/319 [==============================] - 6s 17ms/step - loss: 0.0226 - accuracy: 0.9917 - val_loss: 0.0161 - val_accuracy: 0.9950 - lr: 1.2500e-05
# Epoch 50/50
# 317/319 [============================>.] - ETA: 0s - loss: 0.0243 - accuracy: 0.9918
# Epoch 50: val_accuracy did not improve from 0.99574
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 319/319 [==============================] - 6s 18ms/step - loss: 0.0243 - accuracy: 0.9918 - val_loss: 0.0192 - val_accuracy: 0.9942 - lr: 1.2500e-05

# %%
show_history(historyV2)

modelV2.load_weights(file_pathV2)

evalV2 = modelV2.evaluate(testset, verbose=2)
valV2 = modelV2.evaluate(valset, verbose=2)
trainV2 = modelV2.evaluate(dataV2, verbose=2)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# 33/33 - 1s - loss: 0.0499 - accuracy: 0.9887 - 1s/epoch - 43ms/step
# 1/1 - 0s - loss: 0.0133 - accuracy: 0.9957 - 500ms/epoch - 500ms/step
# 319/319 - 3s - loss: 0.0024 - accuracy: 0.9994 - 3s/epoch - 9ms/step

# %% [markdown]
# # Version III - Massive data augmentation

# %% [markdown]
# ### Data augmentation functions

# %%
import tensorflow_addons as tfa

def process_brightness(image, label):
    
    img = tf.clip_by_value(tfa.image.random_hsv_in_yiq(image, 0.0, 1.0, 1.0, 0.1, 3.0),0,1)
    return img, label

def process_saturation(image, label):
    
    img = tf.clip_by_value(tfa.image.random_hsv_in_yiq(image, 0.0, 1.0, 3.0, 1.0, 1.0),0,1)
    return img, label

def process_contrast(image, label):
    
    img = tf.clip_by_value(tf.image.random_contrast(image, lower=0.1, upper=3.0, seed=None), 0, 1)
    return img, label

def process_hue(image, label):
    
    img = tf.image.random_hue(image, max_delta=0.2, seed=None)
    return img, label

def process_rotate(image, label):
    
    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    return img, label

def process_shear(image, label):
    
    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    sx = tf.random.uniform(shape=(), minval=-0.1, maxval=0.1, dtype=tf.dtypes.float32)
    img = tfa.image.transform(img, [1, sx, -sx*32,   0,1,0,  0,0])
    return img, label

def process_translate(image, label):

    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    tx = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32)
    ty = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32)  
    img = tfa.image.translate(img, [tx,ty])
    return img, label

def process_crop(image, label):
    
    c = tf.random.uniform(shape=(), minval=24, maxval=32, dtype=tf.dtypes.float32)
    img = tf.image.random_crop(image, size=[c,c,3])
    img = tf.image.resize(img ,size= [32,32])
    return img, label

# %%
dataV3 = dataset
# color ops
dataV3 = dataV3.map(process_brightness)
dataV3 = dataV3.concatenate(dataset.map(process_contrast))
dataV3 = dataV3.concatenate(dataset.map(process_hue))
dataV3 = dataV3.concatenate(dataset.map(process_saturation))

#geometry ops
dataV3 = dataV3.concatenate(dataset.map(process_rotate))
dataV3 = dataV3.concatenate(dataset.map(process_shear))
dataV3 = dataV3.concatenate(dataset.map(process_translate))
dataV3 = dataV3.concatenate(dataset.map(process_crop))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)

# %%
modelV3 = model_III(8, 32, 3)

file_pathV3 = f'{log_and_model_path}/DA_modelV3/cp.ckpt'

# %%
callbacksV3 = prepare_callbacks(file_pathV3)

historyV3 = modelV3.fit(dataV3,
          epochs = 50, 
          validation_data = valset, 
          callbacks = callbacksV3)
# Out:
# Epoch 1/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 1.2461 - accuracy: 0.5700
# Epoch 1: val_accuracy improved from -inf to 0.96279, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 56s 16ms/step - loss: 1.2454 - accuracy: 0.5702 - val_loss: 0.1202 - val_accuracy: 0.9628 - lr: 1.0000e-04
# Epoch 2/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 0.2990 - accuracy: 0.8997
# Epoch 2: val_accuracy improved from 0.96279 to 0.96822, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.2991 - accuracy: 0.8997 - val_loss: 0.0868 - val_accuracy: 0.9682 - lr: 1.0000e-04
# Epoch 3/50
# 2547/2550 [============================>.] - ETA: 0s - loss: 0.1671 - accuracy: 0.9438
# Epoch 3: val_accuracy improved from 0.96822 to 0.98411, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 41s 16ms/step - loss: 0.1671 - accuracy: 0.9438 - val_loss: 0.0449 - val_accuracy: 0.9841 - lr: 1.0000e-04
# Epoch 4/50
# 2550/2550 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9622
# Epoch 4: val_accuracy improved from 0.98411 to 0.99031, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 39s 15ms/step - loss: 0.1137 - accuracy: 0.9622 - val_loss: 0.0228 - val_accuracy: 0.9903 - lr: 1.0000e-04
# Epoch 5/50
# 2549/2550 [============================>.] - ETA: 0s - loss: 0.0870 - accuracy: 0.9708
# Epoch 5: val_accuracy improved from 0.99031 to 0.99147, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 39s 15ms/step - loss: 0.0870 - accuracy: 0.9708 - val_loss: 0.0231 - val_accuracy: 0.9915 - lr: 1.0000e-04
# Epoch 6/50
# 2549/2550 [============================>.] - ETA: 0s - loss: 0.0705 - accuracy: 0.9764
# Epoch 6: val_accuracy did not improve from 0.99147
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0706 - accuracy: 0.9764 - val_loss: 0.0246 - val_accuracy: 0.9907 - lr: 1.0000e-04
# Epoch 7/50
# 2550/2550 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 0.9792
# Epoch 7: val_accuracy did not improve from 0.99147
# 2550/2550 [==============================] - 42s 16ms/step - loss: 0.0614 - accuracy: 0.9792 - val_loss: 0.0747 - val_accuracy: 0.9713 - lr: 1.0000e-04
# Epoch 8/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 0.0528 - accuracy: 0.9818
# Epoch 8: val_accuracy did not improve from 0.99147
# 2550/2550 [==============================] - 39s 15ms/step - loss: 0.0528 - accuracy: 0.9819 - val_loss: 0.0367 - val_accuracy: 0.9872 - lr: 1.0000e-04
# Epoch 9/50
# 2550/2550 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9839
# Epoch 9: val_accuracy improved from 0.99147 to 0.99225, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 40s 15ms/step - loss: 0.0479 - accuracy: 0.9839 - val_loss: 0.0199 - val_accuracy: 0.9922 - lr: 1.0000e-04
# Epoch 10/50
# 2549/2550 [============================>.] - ETA: 0s - loss: 0.0425 - accuracy: 0.9860
# Epoch 10: val_accuracy did not improve from 0.99225
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0426 - accuracy: 0.9860 - val_loss: 0.0227 - val_accuracy: 0.9919 - lr: 1.0000e-04
# Epoch 11/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 0.0399 - accuracy: 0.9866
# Epoch 11: val_accuracy improved from 0.99225 to 0.99535, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0398 - accuracy: 0.9866 - val_loss: 0.0106 - val_accuracy: 0.9953 - lr: 1.0000e-04
# Epoch 12/50
# 2550/2550 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9878
# Epoch 12: val_accuracy improved from 0.99535 to 0.99574, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0371 - accuracy: 0.9878 - val_loss: 0.0105 - val_accuracy: 0.9957 - lr: 1.0000e-04
# Epoch 13/50
# 2550/2550 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9887
# Epoch 13: val_accuracy did not improve from 0.99574
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0333 - accuracy: 0.9887 - val_loss: 0.0222 - val_accuracy: 0.9930 - lr: 1.0000e-04
# Epoch 14/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 0.0325 - accuracy: 0.9893
# Epoch 14: val_accuracy did not improve from 0.99574
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0324 - accuracy: 0.9893 - val_loss: 0.0253 - val_accuracy: 0.9922 - lr: 1.0000e-04
# Epoch 15/50
# 2549/2550 [============================>.] - ETA: 0s - loss: 0.0303 - accuracy: 0.9898
# Epoch 15: val_accuracy did not improve from 0.99574
# 2550/2550 [==============================] - 39s 15ms/step - loss: 0.0303 - accuracy: 0.9899 - val_loss: 0.0314 - val_accuracy: 0.9895 - lr: 1.0000e-04
# Epoch 16/50
# 2547/2550 [============================>.] - ETA: 0s - loss: 0.0279 - accuracy: 0.9908
# Epoch 16: val_accuracy did not improve from 0.99574
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2550/2550 [==============================] - 39s 15ms/step - loss: 0.0280 - accuracy: 0.9907 - val_loss: 0.0629 - val_accuracy: 0.9795 - lr: 1.0000e-04
# Epoch 17/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 0.0198 - accuracy: 0.9934
# Epoch 17: val_accuracy did not improve from 0.99574
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0198 - accuracy: 0.9934 - val_loss: 0.0159 - val_accuracy: 0.9950 - lr: 5.0000e-05
# Epoch 18/50
# 2549/2550 [============================>.] - ETA: 0s - loss: 0.0167 - accuracy: 0.9944
# Epoch 18: val_accuracy improved from 0.99574 to 0.99612, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 39s 15ms/step - loss: 0.0167 - accuracy: 0.9944 - val_loss: 0.0143 - val_accuracy: 0.9961 - lr: 5.0000e-05
# Epoch 19/50
# 2549/2550 [============================>.] - ETA: 0s - loss: 0.0153 - accuracy: 0.9947
# Epoch 19: val_accuracy improved from 0.99612 to 0.99767, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 39s 15ms/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.0071 - val_accuracy: 0.9977 - lr: 5.0000e-05
# Epoch 20/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9947
# Epoch 20: val_accuracy did not improve from 0.99767
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0155 - accuracy: 0.9947 - val_loss: 0.0085 - val_accuracy: 0.9969 - lr: 5.0000e-05
# Epoch 21/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 0.0137 - accuracy: 0.9954
# Epoch 21: val_accuracy did not improve from 0.99767
# 2550/2550 [==============================] - 41s 16ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 0.0084 - val_accuracy: 0.9961 - lr: 5.0000e-05
# Epoch 22/50
# 2549/2550 [============================>.] - ETA: 0s - loss: 0.0133 - accuracy: 0.9957
# Epoch 22: val_accuracy did not improve from 0.99767
# 2550/2550 [==============================] - 41s 16ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.0103 - val_accuracy: 0.9969 - lr: 5.0000e-05
# Epoch 23/50
# 2547/2550 [============================>.] - ETA: 0s - loss: 0.0139 - accuracy: 0.9951
# Epoch 23: val_accuracy did not improve from 0.99767
# 2550/2550 [==============================] - 41s 16ms/step - loss: 0.0139 - accuracy: 0.9951 - val_loss: 0.0118 - val_accuracy: 0.9953 - lr: 5.0000e-05
# Epoch 24/50
# 2547/2550 [============================>.] - ETA: 0s - loss: 0.0134 - accuracy: 0.9957
# Epoch 24: val_accuracy did not improve from 0.99767
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0134 - accuracy: 0.9957 - val_loss: 0.0116 - val_accuracy: 0.9961 - lr: 5.0000e-05
# Epoch 25/50
# 2547/2550 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9964
# Epoch 25: val_accuracy did not improve from 0.99767
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0105 - accuracy: 0.9964 - val_loss: 0.0091 - val_accuracy: 0.9973 - lr: 2.5000e-05
# Epoch 26/50
# 2547/2550 [============================>.] - ETA: 0s - loss: 0.0099 - accuracy: 0.9968
# Epoch 26: val_accuracy did not improve from 0.99767
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.0071 - val_accuracy: 0.9977 - lr: 2.5000e-05
# Epoch 27/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9970
# Epoch 27: val_accuracy did not improve from 0.99767
# 2550/2550 [==============================] - 41s 16ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.0060 - val_accuracy: 0.9977 - lr: 2.5000e-05
# Epoch 28/50
# 2547/2550 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9972
# Epoch 28: val_accuracy did not improve from 0.99767
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.0065 - val_accuracy: 0.9977 - lr: 2.5000e-05
# Epoch 29/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 0.0085 - accuracy: 0.9972
# Epoch 29: val_accuracy improved from 0.99767 to 0.99806, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 41s 16ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0059 - val_accuracy: 0.9981 - lr: 2.5000e-05
# Epoch 30/50
# 2549/2550 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9973
# Epoch 30: val_accuracy did not improve from 0.99806
# 2550/2550 [==============================] - 41s 16ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0079 - val_accuracy: 0.9973 - lr: 2.5000e-05
# Epoch 31/50
# 2550/2550 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9974
# Epoch 31: val_accuracy did not improve from 0.99806
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0089 - val_accuracy: 0.9969 - lr: 2.5000e-05
# Epoch 32/50
# 2547/2550 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9972
# Epoch 32: val_accuracy did not improve from 0.99806
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 2550/2550 [==============================] - 41s 16ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0063 - val_accuracy: 0.9973 - lr: 2.5000e-05
# Epoch 33/50
# 2549/2550 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9978
# Epoch 33: val_accuracy improved from 0.99806 to 0.99845, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
# 2550/2550 [==============================] - 41s 16ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0065 - val_accuracy: 0.9984 - lr: 1.2500e-05
# Epoch 34/50
# 2547/2550 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9978
# Epoch 34: val_accuracy did not improve from 0.99845
# 2550/2550 [==============================] - 39s 15ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0063 - val_accuracy: 0.9981 - lr: 1.2500e-05
# Epoch 35/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9980
# Epoch 35: val_accuracy did not improve from 0.99845
# 2550/2550 [==============================] - 41s 16ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0088 - val_accuracy: 0.9969 - lr: 1.2500e-05
# Epoch 36/50
# 2547/2550 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9979
# Epoch 36: val_accuracy did not improve from 0.99845
# 2550/2550 [==============================] - 39s 15ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0078 - val_accuracy: 0.9977 - lr: 1.2500e-05
# Epoch 37/50
# 2550/2550 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9983
# Epoch 37: val_accuracy did not improve from 0.99845
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 2550/2550 [==============================] - 40s 15ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0056 - val_accuracy: 0.9984 - lr: 6.2500e-06
# Epoch 47/50
# 2550/2550 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9983
# Epoch 47: val_accuracy did not improve from 0.99845
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0074 - val_accuracy: 0.9984 - lr: 6.2500e-06
# Epoch 48/50
# 2547/2550 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9987
# Epoch 48: val_accuracy did not improve from 0.99845
# 2550/2550 [==============================] - 40s 16ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0061 - val_accuracy: 0.9984 - lr: 6.2500e-06
# Epoch 49/50
# 2548/2550 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9985
# Epoch 49: val_accuracy improved from 0.99845 to 0.99884, saving model to c:/work/vcpi/dl05//DA_modelV3\cp.ckpt
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 2550/2550 [==============================] - 38s 15ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0061 - val_accuracy: 0.9988 - lr: 6.2500e-06
# Epoch 50/50
# 2550/2550 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9986
# Epoch 50: val_accuracy did not improve from 0.99884
# 2550/2550 [==============================] - 38s 15ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0053 - val_accuracy: 0.9984 - lr: 3.1250e-06

# %%
show_history(historyV3)

modelV3.load_weights(file_pathV3)

evalV3 = modelV3.evaluate(testset, verbose=2)
valV3 = modelV3.evaluate(valset, verbose=2)
trainV3 = modelV3.evaluate(dataV3, verbose=2)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# 33/33 - 1s - loss: 0.0449 - accuracy: 0.9940 - 1s/epoch - 33ms/step
# 1/1 - 0s - loss: 0.0061 - accuracy: 0.9988 - 498ms/epoch - 498ms/step
# 2550/2550 - 13s - loss: 9.2322e-04 - accuracy: 0.9998 - 13s/epoch - 5ms/step

# %%
show_accuracies(['V1', 'V2', 'V3'], [evalV1[1], evalV2[1], evalV3[1]], [valV1[1], valV2[1], valV3[1]])

# %%
numpy_labels = []
numpy_images = []
pred = []

for images, labels in testset.take(-1):  # take all batches of dataset
    numpy_images.extend(images.numpy())
    numpy_labels.extend(labels.numpy())
    pred.extend(modelV3.predict(images.numpy()))


show_misclassified(pred, numpy_labels, numpy_images, int((4170 - 4170*.9933)/3 + 1))
# Out:
# 4/4 [==============================] - 0s 88ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 17ms/step
# 30

# %%
all_labels = [np.argmax(x) for x in numpy_labels]
all_preds = [np.argmax(x) for x in pred]
    
conf_mat = tf.math.confusion_matrix(all_labels, all_preds)

show_confusion_matrix(conf_mat.numpy(), 8)

# %% [markdown]
# ### Further Reading
#
# A Complete Guide to Data Augmentation: https://www.datacamp.com/tutorial/complete-guide-data-augmentation
#
# Data Augmentation Techniques: https://research.aimultiple.com/data-augmentation-techniques/
#
# The Essential Guide to Data Augmentation: https://www.v7labs.com/blog/data-augmentation-guide
